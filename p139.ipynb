# %%
import pandas as pd
acci = pd.read_csv('acci.csv', engine='python')
acci.head()
# Out:
#           법규위반 주야  발생건수  사망자수   부상자수    중상    경상  부상신고
# 0           과속  주   159    34    334   140   178    16
# 1           과속  야   218    73    348   200   139     9
# 2  교차로 통행방법 위반  주  8817    82  14031  3915  9530   586
# 3  교차로 통행방법 위반  야  5904    29   9728  2401  6884   443
# 4           기타  주  9388   141  14070  4271  9217   582

# %%
import pandas as pd
food = pd.read_csv('food.csv', engine='python')
food.head()
# Out:
#   Series_reference   Period  Data_value   STATUS  UNITS  \
# 0      CPIM.SE9S01  1999.06         645  REVISED  Index
# 1      CPIM.SE9S01  1999.07         647  REVISED  Index
# 2      CPIM.SE9S01  1999.08         645  REVISED  Index
# 3      CPIM.SE9S01  1999.09         644  REVISED  Index
# 4      CPIM.SE9S01  1999.10         641  REVISED  Index
#
#                        Subject  \
# 0  Consumers Price Index - CPI
# 1  Consumers Price Index - CPI
# 2  Consumers Price Index - CPI
# 3  Consumers Price Index - CPI
# 4  Consumers Price Index - CPI
#
#                                                Group       Series_title_1
# 0  Food Price Index for New Zealand, Seasonally a...  Seasonally adjusted
# 1  Food Price Index for New Zealand, Seasonally a...  Seasonally adjusted
# 2  Food Price Index for New Zealand, Seasonally a...  Seasonally adjusted
# 3  Food Price Index for New Zealand, Seasonally a...  Seasonally adjusted
# ...

# %%
import pandas as pd
from numpy import NaN
robots = [[24, 23680], [35, NaN], [46, 47350], [27, NaN]]
data = pd.DataFrame(robots, columns=['max_speed', 'price'])
mean = data['price'].mean()
mean
# Out:
# 35515.0

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(1000)
plt.hist(x, bins=np.linspace(-5, 5, 21))
# Out:
# (array([  0.,   0.,   0.,   2.,   4.,  13.,  39.,  81., 169., 195., 187.,
#         132., 102.,  57.,  15.,   2.,   1.,   1.,   0.,   0.]),
#  array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#          0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ]),
#  <a list of 20 Patch objects>)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  8.,  40., 108., 201., 265., 207., 123.,  39.,   7.,   2.]),
#  array([-3.001052  , -2.32979165, -1.65853129, -0.98727094, -0.31601058,
#          0.35524977,  1.02651013,  1.69777048,  2.36903084,  3.04029119,
#          3.71155155]),
#  <a list of 10 Patch objects>)

# %%
import pandas as pd
ary = [[2, 2], [4, 4], [6, 6], [8, 8], [10, 10]]
data = pd.DataFrame(ary, columns=['수온', '상온'])
data['수온'] = data['수온']/data['수온'].max()
data['상온'] = data['상온']/data['상온'].max()
data
# Out:
#     수온   상온
# 0  0.2  0.2
# 1  0.4  0.4
# 2  0.6  0.6
# 3  0.8  0.8
# 4  1.0  1.0

# %%
import numpy as np
import pandas as pd
price = np.random.randint(100, size=8)*10000
cars = pd.DataFrame(price, columns=['price'])
group_names = ['저급', ['중급'], ['고급']
cars['Level'], mybin = pd.cut(cars['price'], 3, labels=group_names, retbins=True)
cars
# Out:
#   File "<ipython-input-16-87c8d24e3f47>", line 6
#     cars['Level'], mybin = pd.cut(cars['price'], 3, labels=group_names, retbins=True)
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
ary = [1, 1.1, '손'], [2, 2.2, '날개'], [3, 3.3, '손']
data = pd.DataFrame(ary, column=['수온', '상온', 'hand'])
data = pd.concat([data, pd.get_dummies(data['hand'])], axis=1, sort=False)
data
print(mybin)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-525aa8ba345e> in <module>
#       2 import numpy as np
#       3 ary = [1, 1.1, '손'], [2, 2.2, '날개'], [3, 3.3, '손']
# ----> 4 data = pd.DataFrame(ary, column=['수온', '상온', 'hand'])
#       5 data = pd.concat([data, pd.get_dummies(data['hand'])], axis=1, sort=False)
#       6 data
#
# TypeError: __init__() got an unexpected keyword argument 'column'

# %%
import pandas as pd
import numpy as np
from numpy import NaN
ary = [[19, 162, '축구'], [17, 169, '야구'], [39, 181, '농구'], [27, 178, NaN], [37, 183, '농구'], [49, NaN, '축구']]
data = pd.DataFrame(ary, columns=['나이', '키', '운동'])
data
# Out:
#    나이      키   운동
# 0  19  162.0   축구
# 1  17  169.0   야구
# 2  39  181.0   농구
# 3  27  178.0  NaN
# 4  37  183.0   농구
# 5  49    NaN   축구

# %%
#1
import pandas as pd
import numpy as np
from numpy import NaN
ary = [[19, 162, '축구'], [17, 169, '야구'], [39, 181, '농구'], [27, 178, NaN], [37, 183, '농구'], [49, NaN, '축구']]
data = pd.DataFrame(ary, columns=['나이', '키', '운동'])
group_names = ['청년', '중년', '장년']
data['연령대'], mybin = pd.cut(data['나이'], 3, labels=group_names, retbins=True)
print(mybin)
data
# Out:
# [16.968      27.66666667 38.33333333 49.        ]
#    나이      키   운동 연령대
# 0  19  162.0   축구  청년
# 1  17  169.0   야구  청년
# 2  39  181.0   농구  장년
# 3  27  178.0  NaN  청년
# 4  37  183.0   농구  중년
# 5  49    NaN   축구  장년

# %%
#2
import pandas as pd
import numpy as np
from numpy import NaN
ary = [[19, 162, '축구'], [17, 169, '야구'], [39, 181, '농구'], [27, 178, NaN], [37, 183, '농구'], [49, NaN, '축구']]
data = pd.DataFrame(ary, columns=['나이', '키', '운동'])
group_names = ['청년', '중년', '장년']
data['연령대'], mybin = pd.cut(data['나이'], 3, labels=group_names, retbins=True)
data.dropna(subset=['운동'], axis=0, inplace=True)
data
# Out:
# [16.968      27.66666667 38.33333333 49.        ]
#    나이      키  운동 연령대
# 0  19  162.0  축구  청년
# 1  17  169.0  야구  청년
# 2  39  181.0  농구  장년
# 4  37  183.0  농구  중년
# 5  49    NaN  축구  장년

# %%
#3
import pandas as pd
import numpy as np
from numpy import NaN
ary = [[19, 162, '축구'], [17, 169, '야구'], [39, 181, '농구'], [27, 178, NaN], [37, 183, '농구'], [49, NaN, '축구']]
data = pd.DataFrame(ary, columns=['나이', '키', '운동'])
group_names = ['청년', '중년', '장년']
data['연령대'], mybin = pd.cut(data['나이'], 3, labels=group_names, retbins=True)
data.dropna(subset=['운동'], axis=0, inplace=True)
mean = data['키'].mean()
data.replace(NaN, mean, inplace=True)
data
# Out:
#    나이       키  운동 연령대
# 0  19  162.00  축구  청년
# 1  17  169.00  야구  청년
# 2  39  181.00  농구  장년
# 4  37  183.00  농구  중년
# 5  49  173.75  축구  장년

# %%
#4
import pandas as pd
import numpy as np
from numpy import NaN
ary = [[19, 162, '축구'], [17, 169, '야구'], [39, 181, '농구'], [27, 178, NaN], [37, 183, '농구'], [49, NaN, '축구']]
data = pd.DataFrame(ary, columns=['나이', '키', '운동'])
group_names = ['청년', '중년', '장년']
data['연령대'], mybin = pd.cut(data['나이'], 3, labels=group_names, retbins=True)
data.dropna(subset=['운동'], axis=0, inplace=True)
mean=data['키'].mean()
data.replace(NaN, mean, inplace=True)
data=pd.concat([data, pd.get_dummies(data['운동'])], axis=1, sort=True)
data
# Out:
#    나이       키  운동 연령대  농구  야구  축구
# 0  19  162.00  축구  청년   0   0   1
# 1  17  169.00  야구  청년   0   1   0
# 2  39  181.00  농구  장년   1   0   0
# 4  37  183.00  농구  중년   1   0   0
# 5  49  173.75  축구  장년   0   0   1

# %%
#5
import pandas as pd
import numpy as np
from numpy import NaN
ary = [[19, 162, '축구'], [17, 169, '야구'], [39, 181, '농구'], [27, 178, NaN], [37, 183, '농구'], [49, NaN, '축구']]
data = pd.DataFrame(ary, columns=['나이', '키', '운동'])
group_names = ['청년', '중년', '장년']
data['연령대'], mybin = pd.cut(data['나이'], 3, labels=group_names, retbins=True)
data.dropna(subset=['운동'], axis=0, inplace=True)
mean=data['키'].mean()
data.replace(NaN, mean, inplace=True)
data=pd.concat([data, pd.get_dummies(data['운동'])], axis=1, sort=True)
data['키'] = (data['키']-data['키'].min())/(data['키'].max()-data['키'].min())
data
# Out:
#    나이         키  운동 연령대  농구  야구  축구
# 0  19  0.000000  축구  청년   0   0   1
# 1  17  0.333333  야구  청년   0   1   0
# 2  39  0.904762  농구  장년   1   0   0
# 4  37  1.000000  농구  중년   1   0   0
# 5  49  0.559524  축구  장년   0   0   1
